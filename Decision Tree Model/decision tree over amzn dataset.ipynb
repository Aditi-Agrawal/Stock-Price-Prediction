# %% [markdown]
# # ALGORITHM - DECISION TREE

# %% [markdown]
# In this model, we are using Machine Leaning algorithm called decision tree.

# %% [markdown]
# # Importing libraries

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
import numpy as np
import pandas as pd

# %% [markdown]
# # Load the data

# %%
#storing data into a variable
df = pd.read_csv('AMZN.csv')

# %%
df
# Out:
#             Date         Open         High          Low        Close  \
# 0     1997-05-15     2.437500     2.500000     1.927083     1.958333
# 1     1997-05-16     1.968750     1.979167     1.708333     1.729167
# 2     1997-05-19     1.760417     1.770833     1.625000     1.708333
# 3     1997-05-20     1.729167     1.750000     1.635417     1.635417
# 4     1997-05-21     1.635417     1.645833     1.375000     1.427083
# ...          ...          ...          ...          ...          ...
# 6252  2022-03-18  3136.260010  3231.879883  3120.219971  3225.010010
# 6253  2022-03-21  3222.419922  3261.679932  3191.060059  3229.830078
# 6254  2022-03-22  3236.110107  3323.340088  3233.979980  3297.780029
# 6255  2022-03-23  3274.100098  3327.399902  3253.739990  3268.159912
# 6256  2022-03-24  3274.989990  3282.370117  3201.000000  3272.989990
#
#         Adj Close    Volume
# 0        1.958333  72156000
# 1        1.729167  14700000
# 2        1.708333   6106800
# 3        1.635417   5467200
# 4        1.427083  18853200
# ...           ...       ...
# 6252  3225.010010   5141300
# 6253  3229.830078   3326900
# 6254  3297.780029   3204300
# 6255  3268.159912   2790600
# 6256  3272.989990   2834900
#
# [6257 rows x 7 columns]

# %%
#set date as the index of the data
df = df.set_index(pd.DatetimeIndex(df['Date'].values))
df
# Out:
#                   Date         Open         High          Low        Close  \
# 1997-05-15  1997-05-15     2.437500     2.500000     1.927083     1.958333
# 1997-05-16  1997-05-16     1.968750     1.979167     1.708333     1.729167
# 1997-05-19  1997-05-19     1.760417     1.770833     1.625000     1.708333
# 1997-05-20  1997-05-20     1.729167     1.750000     1.635417     1.635417
# 1997-05-21  1997-05-21     1.635417     1.645833     1.375000     1.427083
# ...                ...          ...          ...          ...          ...
# 2022-03-18  2022-03-18  3136.260010  3231.879883  3120.219971  3225.010010
# 2022-03-21  2022-03-21  3222.419922  3261.679932  3191.060059  3229.830078
# 2022-03-22  2022-03-22  3236.110107  3323.340088  3233.979980  3297.780029
# 2022-03-23  2022-03-23  3274.100098  3327.399902  3253.739990  3268.159912
# 2022-03-24  2022-03-24  3274.989990  3282.370117  3201.000000  3272.989990
#
#               Adj Close    Volume
# 1997-05-15     1.958333  72156000
# 1997-05-16     1.729167  14700000
# 1997-05-19     1.708333   6106800
# 1997-05-20     1.635417   5467200
# 1997-05-21     1.427083  18853200
# ...                 ...       ...
# 2022-03-18  3225.010010   5141300
# 2022-03-21  3229.830078   3326900
# 2022-03-22  3297.780029   3204300
# 2022-03-23  3268.159912   2790600
# 2022-03-24  3272.989990   2834900
#
# [6257 rows x 7 columns]

# %%
df.index.name='Date'
df
# Out:
#                   Date         Open         High          Low        Close  \
# Date
# 1997-05-15  1997-05-15     2.437500     2.500000     1.927083     1.958333
# 1997-05-16  1997-05-16     1.968750     1.979167     1.708333     1.729167
# 1997-05-19  1997-05-19     1.760417     1.770833     1.625000     1.708333
# 1997-05-20  1997-05-20     1.729167     1.750000     1.635417     1.635417
# 1997-05-21  1997-05-21     1.635417     1.645833     1.375000     1.427083
# ...                ...          ...          ...          ...          ...
# 2022-03-18  2022-03-18  3136.260010  3231.879883  3120.219971  3225.010010
# 2022-03-21  2022-03-21  3222.419922  3261.679932  3191.060059  3229.830078
# 2022-03-22  2022-03-22  3236.110107  3323.340088  3233.979980  3297.780029
# 2022-03-23  2022-03-23  3274.100098  3327.399902  3253.739990  3268.159912
# 2022-03-24  2022-03-24  3274.989990  3282.370117  3201.000000  3272.989990
#
#               Adj Close    Volume
# Date
# 1997-05-15     1.958333  72156000
# 1997-05-16     1.729167  14700000
# 1997-05-19     1.708333   6106800
# 1997-05-20     1.635417   5467200
# 1997-05-21     1.427083  18853200
# ...                 ...       ...
# 2022-03-18  3225.010010   5141300
# 2022-03-21  3229.830078   3326900
# 2022-03-22  3297.780029   3204300
# 2022-03-23  3268.159912   2790600
# 2022-03-24  3272.989990   2834900
#
# [6257 rows x 7 columns]

# %%
# Here with the help of this algorithm we are predicting whether the price of stock market will increase or decrease.
# Adding a column 'Price_up' where 1 indicate increasing and 0 indicates decreasing.
df['Price_up']=np.where(df['Close'].shift(-1)>df['Close'],1, 0)
df = df.drop(columns=['Date'])
df
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1997-05-15     2.437500     2.500000     1.927083     1.958333     1.958333
# 1997-05-16     1.968750     1.979167     1.708333     1.729167     1.729167
# 1997-05-19     1.760417     1.770833     1.625000     1.708333     1.708333
# 1997-05-20     1.729167     1.750000     1.635417     1.635417     1.635417
# 1997-05-21     1.635417     1.645833     1.375000     1.427083     1.427083
# ...                 ...          ...          ...          ...          ...
# 2022-03-18  3136.260010  3231.879883  3120.219971  3225.010010  3225.010010
# 2022-03-21  3222.419922  3261.679932  3191.060059  3229.830078  3229.830078
# 2022-03-22  3236.110107  3323.340088  3233.979980  3297.780029  3297.780029
# 2022-03-23  3274.100098  3327.399902  3253.739990  3268.159912  3268.159912
# 2022-03-24  3274.989990  3282.370117  3201.000000  3272.989990  3272.989990
#
#               Volume  Price_up
# Date
# 1997-05-15  72156000         0
# 1997-05-16  14700000         0
# 1997-05-19   6106800         0
# 1997-05-20   5467200         0
# 1997-05-21  18853200         0
# ...              ...       ...
# 2022-03-18   5141300         1
# 2022-03-21   3326900         1
# 2022-03-22   3204300         0
# 2022-03-23   2790600         1
# 2022-03-24   2834900         0
#
# [6257 rows x 7 columns]

# %%
df.shape
# Out:
# (6257, 7)

# %%
#split the dataset into feature and target dataset.
X = df.iloc[:, 0:df.shape[1]-1].values
Y = df.iloc[:,df.shape[1]-1].values

# %%
#split the dataset into 80% and 20%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2)

# %% [markdown]
# # CREATE AND TRAIN THE MODEL

# %%
#create the model
tree = DecisionTreeClassifier().fit(X_train, Y_train)

# %% [markdown]
# # PERFORMANCE OF THE MODEL

# %%
#how well the model did on test dataset
print(tree.score(X_test, Y_test))
# Out:
# 0.5039936102236422

# %%
tree_predictions = tree.predict(X_test)
print(tree_predictions)
# Out:
# [1 0 0 ... 1 0 0]

# %%
Y_test
# Out:
# array([1, 1, 0, ..., 1, 0, 1])

# %% [markdown]
# the end
